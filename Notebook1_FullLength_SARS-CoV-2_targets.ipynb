# %%
import pandas as pd;
import numpy as np;
import glob;
import operator;
from Bio import SeqIO

# %% [markdown]
# Read in virus sequence

# %%
fn_virusgenome = "data/NC_045512.2.fasta.fa";
for record in SeqIO.parse (fn_virusgenome, "fasta"):
    viruslength = len (record.seq);
    print ("Read in virus %s with sequence length %d" % (record.id, viruslength));
# Out:
# Read in virus NC_045512.2_Severe_acute_respiratory_syndrome_coronavirus_2_isolate_Wuhan-Hu-1,_complete_genome with sequence length 29903

# %% [markdown]
# Read in binding-site predictions

# %%
fns_predictions_sense = glob.glob("data/rna22v2-predictions/sense/*.txt");
fns_predictions_revcomp = glob.glob("data/rna22v2-predictions/revcomp/*.txt");
data_predictions_sense = pd.concat(map(lambda file: pd.read_csv(file, sep="\t", header=None), fns_predictions_sense), ignore_index=True)
data_predictions_revcomp = pd.concat(map(lambda file: pd.read_csv(file, sep="\t", header=None), fns_predictions_revcomp), ignore_index=True)

# %% [markdown]
# Add 1-indexed start/end coordinates columns from predictions into the pandas data frame.  Importantly, the negative-sense prediction coordinates will be converted so that all coordinates are relative to the original positive-sense strand.

# %%
COLUMNS_SEQSPAN = 2;
COLUMNS_SEQSPAN_SPLIT_START = 2;
COLUMNS_SEQSPAN_SPLIT_END = 3;
COLUMNS_ADDSTART = 'StartCoord';
COLUMNS_ADDEND = 'EndCoord';

# add start/end for sense predictions
coords = data_predictions_sense[COLUMNS_SEQSPAN].str.split (pat='_');
data_predictions_sense[COLUMNS_ADDSTART] = [int (myindex[COLUMNS_SEQSPAN_SPLIT_START]) for myindex in coords]
data_predictions_sense[COLUMNS_ADDEND] = [int (myindex[COLUMNS_SEQSPAN_SPLIT_END]) for myindex in coords]

# add start/end for negative-sense predictions. Negative-sense prediction coordinates will be converted so that all coordinates are relative to the original positive-sense strand
coords = data_predictions_revcomp[COLUMNS_SEQSPAN].str.split (pat='_');
data_predictions_revcomp[COLUMNS_ADDEND] = [(viruslength - int (myindex[COLUMNS_SEQSPAN_SPLIT_START]) + 1) for myindex in coords]
data_predictions_revcomp[COLUMNS_ADDSTART] = [(viruslength - int (myindex[COLUMNS_SEQSPAN_SPLIT_END]) + 1) for myindex in coords]

# %% [markdown]
# Find intersections between insilico target predictions and annotated genome regions

# %%
# return True if there is at least 1nt between coordinate sets A and B
def check_any_overlap (a_start, a_end, b_start, b_end):
    if (b_start >= a_start and b_start <= a_end):
        return True;
    if (b_end >= a_start and b_end <= a_end):
        return True;
    return False;

# %%
# read in virus features file
fn_virusfeatures = "data/WHCV_features.txt";
data_virusfeatures = pd.read_csv(fn_virusfeatures, sep="\t", header=0)

# %%
data_predictions_sense["strand"] = 'positive-sense';
data_predictions_revcomp["strand"] = 'negative-sense';

for index, virusfeaturerow in data_virusfeatures.iterrows ():
        virusfeaturestart = virusfeaturerow['Start'];
        virusfeatureend = virusfeaturerow['End'];
                
        newLogitFeatureColumn = "%s|%s" % (virusfeaturerow['Category'], virusfeaturerow['Subcategory']);
        # positive-sense
        colresult = map(lambda predrow: check_any_overlap (virusfeaturestart, virusfeatureend, predrow[1]['StartCoord'], predrow[1]['EndCoord']), data_predictions_sense.iterrows ())
        data_predictions_sense[newLogitFeatureColumn] = list (colresult);
        
        # negative-sense
        colresult = map(lambda predrow: check_any_overlap (virusfeaturestart, virusfeatureend, predrow[1]['StartCoord'], predrow[1]['EndCoord']), data_predictions_revcomp.iterrows ())
        data_predictions_revcomp[newLogitFeatureColumn] = list (colresult);

# %% [markdown]
# Filter miR's based on desired attributes

# %%
data_bothstrands = pd.concat ([data_predictions_sense, data_predictions_revcomp], axis=0, ignore_index=True);

scoredcolumnnames = [];
for index, virusfeaturerow in data_virusfeatures.iterrows ():
    
    # these are the features we'll include scores for
    if (virusfeaturerow['Category'] == 'FULLGENOME' or
        virusfeaturerow['Category'] == 'GENE' or
        virusfeaturerow['Category'] == 'UTR'):
        
        newLogitFeatureColumn = "%s|%s" % (virusfeaturerow['Category'], virusfeaturerow['Subcategory']);
        scoredcolumnnames.append (newLogitFeatureColumn);
        
mirscores = {};
for _, datarow in data_bothstrands.iterrows ():
    if (datarow[scoredcolumnnames].sum() > 0):
        if mirscores.get (datarow[0]) == None:
            mirscores[datarow[0]] = 1;
        else:
            mirscores[datarow[0]] = mirscores[datarow[0]] + 1;

# %%
sorted_mirscores = sorted(mirscores.items(), key=operator.itemgetter(1), reverse=True)
scores = list (mirscores.values ());
minvalue = 1; # must have at least 1 intersection
survivedmirs = [k for k,v in mirscores.items() if int(v) >= minvalue]

# %%
# read in miR coordinates (which are already sorted)
fn_sortedmircoords = "data/mature.coords.sorted.dupsallowed.mirbase22.5cols.txt";
data_sortedmircoords = pd.read_csv(fn_sortedmircoords, sep="\t", header=None)

# %%
col_coordfile_mirname = 4; # 0-indexed column that includes the miR name inside fn_sortedmircoords 
col_coordfile_chrom = 0;
col_coordfile_start = 2;

clusterddistance = 10000; # tag miR's if they are within this many NT from the start site of the previous regardless of strand
prevmir_chrom = None;
premir_start = None;

clusternum = 0;
clusteroutput = {};
emptyclusterrecord = { "uniquelocations": 0,
                       "numincluster": 0,
                       "details": ""
                     };

for index, sortedmircoords in data_sortedmircoords.iterrows():
    for survivedmir in survivedmirs:
        if survivedmir == sortedmircoords[col_coordfile_mirname]:
            appendtext = "";
            
            if ((sortedmircoords[col_coordfile_chrom] == prevmir_chrom) and
               (sortedmircoords[col_coordfile_start] - premir_start <= clusterddistance)):
        
                appendtext = "POTENTIAL CLUSTER: this miR is %d distance from the previously listed miR\n" % (sortedmircoords[col_coordfile_start] - premir_start);
            else:
                clusternum += 1;
                clusteroutput[clusternum] = dict (emptyclusterrecord);

            clusteroutput[clusternum]["numincluster"] += 1;
            clusteroutput[clusternum]["uniquelocations"] += mirscores[survivedmir];
            appendtext += "miR: %s (total uniq predicted binding locations: %d)\n" % (survivedmir, mirscores[survivedmir]);
            
            matchmir = data_bothstrands.loc[(data_bothstrands[0] == survivedmir) & (data_bothstrands["strand"] == 'positive-sense'), scoredcolumnnames];
            nonzeros = matchmir.sum()>0;
            if (sum (nonzeros) > 0):
                appendtext += "Positive-Sense: \n";
                appendtext += matchmir.sum()[nonzeros].to_string ();
                appendtext += "\n\n";

            matchmir = data_bothstrands.loc[(data_bothstrands[0] == survivedmir) & (data_bothstrands["strand"] == 'negative-sense'), scoredcolumnnames];    
            nonzeros = matchmir.sum()>0;
            if (sum (nonzeros) > 0):
                appendtext += "Negative-Sense: \n";
                appendtext += matchmir.sum()[nonzeros].to_string ();
                appendtext += "\n\n";
                
            clusteroutput[clusternum]["details"] += appendtext;
            
            prevmir_chrom = sortedmircoords[col_coordfile_chrom];
            premir_start = sortedmircoords[col_coordfile_start];

# %%
# sort hash in desending order by uniquelocations & numincluster
sortedoutput = [v for k, v in sorted(clusteroutput.items(), key=lambda item: (-item[1]["uniquelocations"], -item[1]["numincluster"]))]

for sortoutput in sortedoutput:
    print ("---------------- Cluster Start -----------------------------------")
    print ("unique_predicted_target_locations: %d" % (sortoutput["uniquelocations"]))
    print ("number_of_miRNAs_in_cluster: %d" % (sortoutput["numincluster"]))
    print ("%s" % (sortoutput["details"]))
    print ();
# Out:
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 450
# number_of_miRNAs_in_cluster: 67
# miR: hsa_miR_379_5p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               3
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_379_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1231 distance from the previously listed miR
# miR: hsa_miR_411_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 35 distance from the previously listed miR
# miR: hsa_miR_411_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 425 distance from the previously listed miR
# miR: hsa_miR_299_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 32 distance from the previously listed miR
# miR: hsa_miR_299_3p (total uniq predicted binding locations: 11)
# Positive-Sense:
# FULLGENOME|fullspan    5
# GENE|1AB               3
# GENE|S                 1
# GENE|M                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               5
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 1189 distance from the previously listed miR
# miR: hsa_miR_380_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               1
# GENE|S                 1
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 35 distance from the previously listed miR
# miR: hsa_miR_380_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 564 distance from the previously listed miR
# miR: hsa_miR_1197 (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 127 distance from the previously listed miR
# miR: hsa_miR_323a_5p (total uniq predicted binding locations: 24)
# Positive-Sense:
# FULLGENOME|fullspan    10
# GENE|1AB                8
# GENE|S                  1
# GENE|M                  1
#
# Negative-Sense:
# FULLGENOME|fullspan    14
# GENE|1AB               10
# GENE|S                  1
# GENE|3a                 2
# GENE|N                  1
# GENE|9b                 1
#
# POTENTIAL CLUSTER: this miR is 35 distance from the previously listed miR
# miR: hsa_miR_323a_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 252 distance from the previously listed miR
# miR: hsa_miR_758_5p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
# GENE|9a                1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_758_3p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|7a                1
#
# POTENTIAL CLUSTER: this miR is 726 distance from the previously listed miR
# miR: hsa_miR_329_5p (total uniq predicted binding locations: 13)
# Positive-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               2
# GENE|S                 1
# GENE|N                 3
# GENE|9a                1
# GENE|9b                1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               3
# GENE|S                 1
# GENE|3a                1
# GENE|3b                1
# GENE|M                 1
# GENE|N                 1
# GENE|9a                1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_329_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 280 distance from the previously listed miR
# miR: hsa_miR_329_5p (total uniq predicted binding locations: 13)
# Positive-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               2
# GENE|S                 1
# GENE|N                 3
# GENE|9a                1
# GENE|9b                1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               3
# GENE|S                 1
# GENE|3a                1
# GENE|3b                1
# GENE|M                 1
# GENE|N                 1
# GENE|9a                1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_329_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 2497 distance from the previously listed miR
# miR: hsa_miR_494_5p (total uniq predicted binding locations: 15)
# Positive-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               5
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    9
# GENE|1AB               7
# GENE|S                 2
#
# POTENTIAL CLUSTER: this miR is 413 distance from the previously listed miR
# miR: hsa_miR_1193 (total uniq predicted binding locations: 31)
# Positive-Sense:
# FULLGENOME|fullspan    16
# GENE|1AB                9
# GENE|S                  2
# GENE|3a                 1
# GENE|3b                 1
# GENE|M                  1
# GENE|7b                 1
# GENE|N                  1
# GENE|9b                 1
# UTR|5putr               1
#
# Negative-Sense:
# FULLGENOME|fullspan    15
# GENE|1AB               11
# GENE|S                  1
# GENE|3a                 1
# GENE|N                  2
# GENE|9a                 1
# UTR|5putr               1
#
# POTENTIAL CLUSTER: this miR is 3707 distance from the previously listed miR
# miR: hsa_miR_495_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 5926 distance from the previously listed miR
# miR: hsa_miR_376c_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|7a                1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_376c_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|7a                1
#
# POTENTIAL CLUSTER: this miR is 348 distance from the previously listed miR
# miR: hsa_miR_376a_2_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_376a_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 116 distance from the previously listed miR
# miR: hsa_miR_654_5p (total uniq predicted binding locations: 19)
# Positive-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               5
# GENE|S                 2
#
# Negative-Sense:
# FULLGENOME|fullspan    12
# GENE|1AB               10
# GENE|3a                 1
# GENE|3b                 1
# GENE|N                  1
# GENE|9a                 1
#
# POTENTIAL CLUSTER: this miR is 35 distance from the previously listed miR
# miR: hsa_miR_654_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 190 distance from the previously listed miR
# miR: hsa_miR_376b_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|7a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_376b_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 291 distance from the previously listed miR
# miR: hsa_miR_376a_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_376a_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 589 distance from the previously listed miR
# miR: hsa_miR_300 (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 1577 distance from the previously listed miR
# miR: hsa_miR_1185_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_1185_1_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1183 distance from the previously listed miR
# miR: hsa_miR_1185_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_1185_2_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|7a                1
#
# POTENTIAL CLUSTER: this miR is 1677 distance from the previously listed miR
# miR: hsa_miR_381_5p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|M                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 41 distance from the previously listed miR
# miR: hsa_miR_381_3p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 501 distance from the previously listed miR
# miR: hsa_miR_487b_5p (total uniq predicted binding locations: 7)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               2
# GENE|S                 1
# GENE|N                 1
# GENE|9a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# POTENTIAL CLUSTER: this miR is 860 distance from the previously listed miR
# miR: hsa_miR_539_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
# GENE|9b                1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 582 distance from the previously listed miR
# miR: hsa_miR_889_5p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               1
# GENE|M                 1
# GENE|N                 1
# GENE|9a                1
#
# POTENTIAL CLUSTER: this miR is 801 distance from the previously listed miR
# miR: hsa_miR_544a (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|S                 2
#
# POTENTIAL CLUSTER: this miR is 860 distance from the previously listed miR
# miR: hsa_miR_655_5p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    5
# GENE|1AB               4
# GENE|N                 1
# GENE|9a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 2886 distance from the previously listed miR
# miR: hsa_miR_487a_5p (total uniq predicted binding locations: 13)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               3
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    9
# GENE|1AB               7
# GENE|S                 1
# UTR|5putr              1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_487a_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1822 distance from the previously listed miR
# miR: hsa_miR_382_5p (total uniq predicted binding locations: 10)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               7
#
# POTENTIAL CLUSTER: this miR is 378 distance from the previously listed miR
# miR: hsa_miR_134_5p (total uniq predicted binding locations: 12)
# Positive-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               3
# GENE|S                 1
# GENE|N                 2
# GENE|9b                1
#
# Negative-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               6
# UTR|5putr              1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_134_3p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               3
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 532 distance from the previously listed miR
# miR: hsa_miR_668_5p (total uniq predicted binding locations: 9)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|S                 1
# GENE|7a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               6
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_668_3p (total uniq predicted binding locations: 7)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               2
# GENE|M                 1
# UTR|5putr              1
#
# POTENTIAL CLUSTER: this miR is 127 distance from the previously listed miR
# miR: hsa_miR_485_5p (total uniq predicted binding locations: 16)
# Positive-Sense:
# FULLGENOME|fullspan    8
# GENE|1AB               5
# GENE|S                 3
#
# Negative-Sense:
# FULLGENOME|fullspan    8
# GENE|1AB               6
# GENE|S                 1
# GENE|N                 1
# GENE|9b                1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_485_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# POTENTIAL CLUSTER: this miR is 769 distance from the previously listed miR
# miR: hsa_miR_323b_5p (total uniq predicted binding locations: 33)
# Positive-Sense:
# FULLGENOME|fullspan    14
# GENE|1AB               13
# GENE|7a                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    19
# GENE|1AB               15
# GENE|S                  2
# GENE|M                  1
# UTR|3putr               1
#
# POTENTIAL CLUSTER: this miR is 3536 distance from the previously listed miR
# miR: hsa_miR_154_5p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# UTR|5putr              1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_154_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 823 distance from the previously listed miR
# miR: hsa_miR_496 (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1428 distance from the previously listed miR
# miR: hsa_miR_377_5p (total uniq predicted binding locations: 16)
# Positive-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               5
# GENE|S                 1
# GENE|N                 1
# GENE|9b                1
#
# Negative-Sense:
# FULLGENOME|fullspan    9
# GENE|1AB               9
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_377_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 2410 distance from the previously listed miR
# miR: hsa_miR_541_5p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|3a                1
# GENE|7a                1
#
# POTENTIAL CLUSTER: this miR is 44 distance from the previously listed miR
# miR: hsa_miR_541_3p (total uniq predicted binding locations: 18)
# Positive-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               6
# GENE|7a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    11
# GENE|1AB                6
# GENE|S                  2
# GENE|3a                 1
# GENE|3b                 1
# GENE|N                  2
# GENE|9a                 2
#
# POTENTIAL CLUSTER: this miR is 766 distance from the previously listed miR
# miR: hsa_miR_409_5p (total uniq predicted binding locations: 7)
# Positive-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               5
# GENE|3a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 32 distance from the previously listed miR
# miR: hsa_miR_409_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
# GENE|9a                1
#
# POTENTIAL CLUSTER: this miR is 119 distance from the previously listed miR
# miR: hsa_miR_412_5p (total uniq predicted binding locations: 3)
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               1
# GENE|S                 1
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 35 distance from the previously listed miR
# miR: hsa_miR_412_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 106 distance from the previously listed miR
# miR: hsa_miR_369_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 319 distance from the previously listed miR
# miR: hsa_miR_410_5p (total uniq predicted binding locations: 16)
# Positive-Sense:
# FULLGENOME|fullspan    10
# GENE|1AB                6
# GENE|S                  1
# GENE|3a                 1
# GENE|10                 1
# UTR|5putr               1
# UTR|3putr               1
#
# Negative-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               6
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_410_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|10                1
#
# POTENTIAL CLUSTER: this miR is 770 distance from the previously listed miR
# miR: hsa_miR_656_5p (total uniq predicted binding locations: 24)
# Positive-Sense:
# FULLGENOME|fullspan    9
# GENE|1AB               5
# GENE|S                 2
# GENE|7a                1
# GENE|10                1
# UTR|3putr              1
#
# Negative-Sense:
# FULLGENOME|fullspan    15
# GENE|1AB               11
# GENE|S                  3
# GENE|N                  1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 238
# number_of_miRNAs_in_cluster: 75
# miR: hsa_miR_512_3p (total uniq predicted binding locations: 8)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               5
# GENE|N                 1
#
# POTENTIAL CLUSTER: this miR is 2484 distance from the previously listed miR
# miR: hsa_miR_512_3p (total uniq predicted binding locations: 8)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               5
# GENE|N                 1
#
# POTENTIAL CLUSTER: this miR is 5017 distance from the previously listed miR
# miR: hsa_miR_498_5p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|3a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_498_3p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 1460 distance from the previously listed miR
# miR: hsa_miR_520e_5p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
# GENE|9b                1
#
# Negative-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_520e_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 3252 distance from the previously listed miR
# miR: hsa_miR_515_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_515_3p (total uniq predicted binding locations: 10)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|S                 2
# GENE|N                 1
# GENE|9a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               7
#
# POTENTIAL CLUSTER: this miR is 900 distance from the previously listed miR
# miR: hsa_miR_519e_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_519e_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# POTENTIAL CLUSTER: this miR is 2182 distance from the previously listed miR
# miR: hsa_miR_520f_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_520f_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 2809 distance from the previously listed miR
# miR: hsa_miR_515_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_515_3p (total uniq predicted binding locations: 10)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|S                 2
# GENE|N                 1
# GENE|9a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               7
#
# POTENTIAL CLUSTER: this miR is 1425 distance from the previously listed miR
# miR: hsa_miR_519c_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_519c_3p (total uniq predicted binding locations: 3)
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# POTENTIAL CLUSTER: this miR is 1972 distance from the previously listed miR
# miR: hsa_miR_1283 (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# POTENTIAL CLUSTER: this miR is 2401 distance from the previously listed miR
# miR: hsa_miR_520a_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_520a_3p (total uniq predicted binding locations: 7)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|N                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# POTENTIAL CLUSTER: this miR is 3473 distance from the previously listed miR
# miR: hsa_miR_526b_5p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_526b_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 782 distance from the previously listed miR
# miR: hsa_miR_519b_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_519b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 2284 distance from the previously listed miR
# miR: hsa_miR_525_5p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|7a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_525_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               4
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 816 distance from the previously listed miR
# miR: hsa_miR_523_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_523_3p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|N                 1
# GENE|9a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 1593 distance from the previously listed miR
# miR: hsa_miR_518f_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_518f_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 1161 distance from the previously listed miR
# miR: hsa_miR_520b_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 39 distance from the previously listed miR
# miR: hsa_miR_520b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1520 distance from the previously listed miR
# miR: hsa_miR_518b (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|S                 2
#
# POTENTIAL CLUSTER: this miR is 3479 distance from the previously listed miR
# miR: hsa_miR_526a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_526a_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 1165 distance from the previously listed miR
# miR: hsa_miR_520c_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_520c_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1252 distance from the previously listed miR
# miR: hsa_miR_518c_5p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|3a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# UTR|5putr              1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_518c_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 2221 distance from the previously listed miR
# miR: hsa_miR_524_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_524_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               3
# GENE|M                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1267 distance from the previously listed miR
# miR: hsa_miR_517a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
#
# POTENTIAL CLUSTER: this miR is 4326 distance from the previously listed miR
# miR: hsa_miR_521 (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 3464 distance from the previously listed miR
# miR: hsa_miR_520d_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_520d_3p (total uniq predicted binding locations: 6)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               3
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 969 distance from the previously listed miR
# miR: hsa_miR_517b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
#
# POTENTIAL CLUSTER: this miR is 1064 distance from the previously listed miR
# miR: hsa_miR_520g_5p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|7a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|M                 1
# GENE|N                 1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_520g_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 3237 distance from the previously listed miR
# miR: hsa_miR_516b_5p (total uniq predicted binding locations: 8)
# Positive-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               3
# GENE|S                 2
# GENE|3a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|3a                1
# GENE|3b                1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_516b_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 1431 distance from the previously listed miR
# miR: hsa_miR_526a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 2925 distance from the previously listed miR
# miR: hsa_miR_518e_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_518e_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1128 distance from the previously listed miR
# miR: hsa_miR_518a_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_518a_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 3836 distance from the previously listed miR
# miR: hsa_miR_518d_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_518d_3p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|S                 2
#
# POTENTIAL CLUSTER: this miR is 1931 distance from the previously listed miR
# miR: hsa_miR_516b_5p (total uniq predicted binding locations: 8)
# Positive-Sense:
# FULLGENOME|fullspan    6
# GENE|1AB               3
# GENE|S                 2
# GENE|3a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|3a                1
# GENE|3b                1
#
# POTENTIAL CLUSTER: this miR is 45 distance from the previously listed miR
# miR: hsa_miR_516b_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 2443 distance from the previously listed miR
# miR: hsa_miR_518a_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_518a_3p (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 1984 distance from the previously listed miR
# miR: hsa_miR_517c_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 1197 distance from the previously listed miR
# miR: hsa_miR_520h (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|S                 1
#
# POTENTIAL CLUSTER: this miR is 6123 distance from the previously listed miR
# miR: hsa_miR_521 (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 2537 distance from the previously listed miR
# miR: hsa_miR_522_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_522_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|8                 1
#
# POTENTIAL CLUSTER: this miR is 1147 distance from the previously listed miR
# miR: hsa_miR_519a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_519a_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
# POTENTIAL CLUSTER: this miR is 1582 distance from the previously listed miR
# miR: hsa_miR_527 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 2725 distance from the previously listed miR
# miR: hsa_miR_516a_5p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
# GENE|9a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
# GENE|9b                1
#
# POTENTIAL CLUSTER: this miR is 45 distance from the previously listed miR
# miR: hsa_miR_516a_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 1444 distance from the previously listed miR
# miR: hsa_miR_1283 (total uniq predicted binding locations: 3)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# POTENTIAL CLUSTER: this miR is 2903 distance from the previously listed miR
# miR: hsa_miR_516a_5p (total uniq predicted binding locations: 4)
# Positive-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
# GENE|9a                1
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|N                 1
# GENE|9b                1
#
# POTENTIAL CLUSTER: this miR is 45 distance from the previously listed miR
# miR: hsa_miR_516a_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|3a                1
#
# POTENTIAL CLUSTER: this miR is 1165 distance from the previously listed miR
# miR: hsa_miR_519a_2_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 39 distance from the previously listed miR
# miR: hsa_miR_519a_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 122
# number_of_miRNAs_in_cluster: 9
# miR: hsa_miR_3689c (total uniq predicted binding locations: 12)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    11
# GENE|1AB                6
# GENE|S                  2
# GENE|M                  2
# GENE|8                  1
#
# POTENTIAL CLUSTER: this miR is 192 distance from the previously listed miR
# miR: hsa_miR_3689a_3p (total uniq predicted binding locations: 16)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               3
# GENE|S                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    12
# GENE|1AB                8
# GENE|S                  1
# GENE|M                  2
# GENE|N                  1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_3689a_5p (total uniq predicted binding locations: 11)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|M                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    8
# GENE|1AB               5
# GENE|S                 2
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 126 distance from the previously listed miR
# miR: hsa_miR_3689d (total uniq predicted binding locations: 17)
# Positive-Sense:
# FULLGENOME|fullspan    10
# GENE|1AB                9
# GENE|S                  1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               5
# GENE|3a                1
# GENE|N                 1
#
# POTENTIAL CLUSTER: this miR is 506 distance from the previously listed miR
# miR: hsa_miR_3689b_3p (total uniq predicted binding locations: 12)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    11
# GENE|1AB                6
# GENE|S                  2
# GENE|M                  2
# GENE|8                  1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_3689b_5p (total uniq predicted binding locations: 11)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|M                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    8
# GENE|1AB               5
# GENE|S                 2
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 126 distance from the previously listed miR
# miR: hsa_miR_3689d (total uniq predicted binding locations: 17)
# Positive-Sense:
# FULLGENOME|fullspan    10
# GENE|1AB                9
# GENE|S                  1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               5
# GENE|3a                1
# GENE|N                 1
#
# POTENTIAL CLUSTER: this miR is 282 distance from the previously listed miR
# miR: hsa_miR_3689e (total uniq predicted binding locations: 11)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|M                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    8
# GENE|1AB               5
# GENE|S                 2
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 169 distance from the previously listed miR
# miR: hsa_miR_3689f (total uniq predicted binding locations: 15)
# Positive-Sense:
# FULLGENOME|fullspan    4
# GENE|1AB               2
# GENE|M                 1
# GENE|N                 1
#
# Negative-Sense:
# FULLGENOME|fullspan    11
# GENE|1AB                5
# GENE|S                  4
# GENE|M                  1
# UTR|3putr               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 113
# number_of_miRNAs_in_cluster: 4
# miR: hsa_let_7a_5p (total uniq predicted binding locations: 14)
# Positive-Sense:
# FULLGENOME|fullspan    11
# GENE|1AB               10
# GENE|M                  1
#
# Negative-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               2
# GENE|10                1
#
# POTENTIAL CLUSTER: this miR is 832 distance from the previously listed miR
# miR: hsa_miR_4763_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|M                 1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_4763_3p (total uniq predicted binding locations: 68)
# Positive-Sense:
# FULLGENOME|fullspan    38
# GENE|1AB               26
# GENE|S                  6
# GENE|M                  2
# GENE|7a                 2
# GENE|7b                 1
# UTR|5putr               1
#
# Negative-Sense:
# FULLGENOME|fullspan    30
# GENE|1AB               21
# GENE|S                  3
# GENE|7a                 1
# GENE|N                  4
# GENE|9a                 1
# GENE|9b                 1
# GENE|10                 1
#
# POTENTIAL CLUSTER: this miR is 67 distance from the previously listed miR
# miR: hsa_let_7b_5p (total uniq predicted binding locations: 30)
# Positive-Sense:
# FULLGENOME|fullspan    16
# GENE|1AB               12
# GENE|S                  1
# GENE|3a                 2
# GENE|3b                 2
# GENE|M                  1
#
# Negative-Sense:
# FULLGENOME|fullspan    14
# GENE|1AB               12
# GENE|3a                 1
# GENE|3b                 1
# GENE|10                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 98
# number_of_miRNAs_in_cluster: 5
# miR: hsa_miR_449a (total uniq predicted binding locations: 26)
# Positive-Sense:
# FULLGENOME|fullspan    16
# GENE|1AB                8
# GENE|S                  3
# GENE|M                  2
# GENE|N                  2
# GENE|9b                 1
# UTR|3putr               1
#
# Negative-Sense:
# FULLGENOME|fullspan    10
# GENE|1AB                8
# GENE|3a                 1
# GENE|N                  1
#
# POTENTIAL CLUSTER: this miR is 81 distance from the previously listed miR
# miR: hsa_miR_449b_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 39 distance from the previously listed miR
# miR: hsa_miR_449b_5p (total uniq predicted binding locations: 33)
# Positive-Sense:
# FULLGENOME|fullspan    18
# GENE|1AB               10
# GENE|S                  4
# GENE|M                  2
# GENE|N                  1
# UTR|3putr               1
#
# Negative-Sense:
# FULLGENOME|fullspan    15
# GENE|1AB                9
# GENE|S                  2
# GENE|M                  1
# GENE|N                  2
# UTR|3putr               1
#
# POTENTIAL CLUSTER: this miR is 1569 distance from the previously listed miR
# miR: hsa_miR_449c_3p (total uniq predicted binding locations: 5)
# Positive-Sense:
# FULLGENOME|fullspan    3
# GENE|1AB               3
#
# Negative-Sense:
# FULLGENOME|fullspan    2
# GENE|1AB               1
# GENE|E                 1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_449c_5p (total uniq predicted binding locations: 32)
# Positive-Sense:
# FULLGENOME|fullspan    25
# GENE|1AB               19
# GENE|S                  1
# GENE|M                  3
# GENE|N                  1
# GENE|9b                 1
# UTR|3putr               1
#
# Negative-Sense:
# FULLGENOME|fullspan    7
# GENE|1AB               5
# GENE|N                 2
# GENE|9b                1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 92
# number_of_miRNAs_in_cluster: 4
# miR: hsa_miR_6804_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
# POTENTIAL CLUSTER: this miR is 42 distance from the previously listed miR
# miR: hsa_miR_6804_5p (total uniq predicted binding locations: 23)
# Positive-Sense:
# FULLGENOME|fullspan    12
# GENE|1AB                8
# GENE|S                  2
# GENE|3a                 1
# GENE|M                  1
#
# Negative-Sense:
# FULLGENOME|fullspan    11
# GENE|1AB               10
# GENE|7a                 1
#
# POTENTIAL CLUSTER: this miR is 9025 distance from the previously listed miR
# miR: hsa_miR_6802_5p (total uniq predicted binding locations: 18)
# Positive-Sense:
# FULLGENOME|fullspan    10
# GENE|1AB               10
#
# Negative-Sense:
# FULLGENOME|fullspan    8
# GENE|1AB               7
# UTR|5putr              1
#
# POTENTIAL CLUSTER: this miR is 5272 distance from the previously listed miR
# miR: hsa_miR_6803_5p (total uniq predicted binding locations: 50)
# Positive-Sense:
# FULLGENOME|fullspan    25
# GENE|1AB               15
# GENE|S                  5
# GENE|8                  1
# GENE|N                  3
# GENE|9b                 1
# UTR|3putr               1
#
# Negative-Sense:
# FULLGENOME|fullspan    25
# GENE|1AB               19
# GENE|S                  3
# ...
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4326 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_802 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4760_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|7b                1
# GENE|8                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5692b (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5571_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3134 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_563 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5193 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4444 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5688 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_568 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548i (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5704 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_569 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7977 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# UTR|5putr              1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548aq_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_95_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|M                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548i (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_12113 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3684 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_8066 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1243 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6082 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548t_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4636 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|8                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548ae_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3977 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_583 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|M                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_12130 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_12125 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
# GENE|9a                1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3143 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
# GENE|9b                1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4464 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4643 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3662 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4465 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
# GENE|9b                1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1200 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_590_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548o_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|M                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3674 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548i (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4288 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3148 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_2052 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|3a                1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_9903 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|S                 1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7705 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5680 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548a_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3686 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7848_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4540 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4292 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|N                 1
# GENE|9b                1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_651_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|7a                1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_8088 (total uniq predicted binding locations: 1)
# Negative-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1468_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
# UTR|5putr              1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_374a_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_384 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# UTR|3putr              1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4328 (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# UTR|3putr              1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_548i (total uniq predicted binding locations: 1)
# Positive-Sense:
# FULLGENOME|fullspan    1
# GENE|1AB               1
