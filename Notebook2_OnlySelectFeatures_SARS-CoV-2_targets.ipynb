# %%
import pandas as pd;
import numpy as np;
import glob;
import operator;
from Bio import SeqIO

# %% [markdown]
# Read in virus sequence

# %%
fn_virusgenome = "data/NC_045512.2.fasta.fa";
for record in SeqIO.parse (fn_virusgenome, "fasta"):
    viruslength = len (record.seq);
    print ("Read in virus %s with sequence length %d" % (record.id, viruslength));
# Out:
# Read in virus NC_045512.2_Severe_acute_respiratory_syndrome_coronavirus_2_isolate_Wuhan-Hu-1,_complete_genome with sequence length 29903

# %% [markdown]
# Read in binding-site predictions

# %%
fns_predictions_sense = glob.glob("data/rna22v2-predictions/sense/*.txt");
fns_predictions_revcomp = glob.glob("data/rna22v2-predictions/revcomp/*.txt");
data_predictions_sense = pd.concat(map(lambda file: pd.read_csv(file, sep="\t", header=None), fns_predictions_sense), ignore_index=True)
data_predictions_revcomp = pd.concat(map(lambda file: pd.read_csv(file, sep="\t", header=None), fns_predictions_revcomp), ignore_index=True)

# %% [markdown]
# Add 1-indexed start/end coordinates columns from predictions into the pandas data frame.  Importantly, the negative-sense prediction coordinates will be converted so that all coordinates are relative to the positive-sense strand.

# %%
COLUMNS_SEQSPAN = 2;
COLUMNS_SEQSPAN_SPLIT_START = 2;
COLUMNS_SEQSPAN_SPLIT_END = 3;
COLUMNS_ADDSTART = 'StartCoord';
COLUMNS_ADDEND = 'EndCoord';

# add start/end for sense predictions
coords = data_predictions_sense[COLUMNS_SEQSPAN].str.split (pat='_');
data_predictions_sense[COLUMNS_ADDSTART] = [int (myindex[COLUMNS_SEQSPAN_SPLIT_START]) for myindex in coords]
data_predictions_sense[COLUMNS_ADDEND] = [int (myindex[COLUMNS_SEQSPAN_SPLIT_END]) for myindex in coords]

# add start/end for negative-sense predictions. AntiSense prediction coordinates will be converted so that all coordinates are relative to the positive-sense strand
coords = data_predictions_revcomp[COLUMNS_SEQSPAN].str.split (pat='_');
data_predictions_revcomp[COLUMNS_ADDEND] = [(viruslength - int (myindex[COLUMNS_SEQSPAN_SPLIT_START]) + 1) for myindex in coords]
data_predictions_revcomp[COLUMNS_ADDSTART] = [(viruslength - int (myindex[COLUMNS_SEQSPAN_SPLIT_END]) + 1) for myindex in coords]

# %% [markdown]
# Find intersections between insilico target predictions and annotated genome regions

# %%
# return True if there is at least 1nt between coordinate sets A and B
def check_any_overlap (a_start, a_end, b_start, b_end):
    if (b_start >= a_start and b_start <= a_end):
        return True;
    if (b_end >= a_start and b_end <= a_end):
        return True;
    return False;

# %%
# read in virus features file
fn_virusfeatures = "data/WHCV_features.txt";
data_virusfeatures = pd.read_csv(fn_virusfeatures, sep="\t", header=0)

# %%
data_predictions_sense["strand"] = 'positive-sense';
data_predictions_revcomp["strand"] = 'negative-sense';

for index, virusfeaturerow in data_virusfeatures.iterrows ():
        virusfeaturestart = virusfeaturerow['Start'];
        virusfeatureend = virusfeaturerow['End'];
        
        # for a few categories, lets pad the feature by a few base pairs
        if (virusfeaturerow['Category'] == 'TRS' or 
            virusfeaturerow['Category'] == 'SLIP' or
            virusfeaturerow['Category'] == 'KNOT'):
    
            virusfeaturestart = virusfeaturestart - 5;
            virusfeatureend = virusfeatureend + 5;
            
        if (virusfeaturerow['Category'] == 'STARTGENE'):
            virusfeaturestart = virusfeaturestart - 10;
            virusfeatureend = virusfeatureend + 10;
        
        newLogitFeatureColumn = "%s|%s" % (virusfeaturerow['Category'], virusfeaturerow['Subcategory']);
        # positive-sense
        colresult = map(lambda predrow: check_any_overlap (virusfeaturestart, virusfeatureend, predrow[1]['StartCoord'], predrow[1]['EndCoord']), data_predictions_sense.iterrows ())
        data_predictions_sense[newLogitFeatureColumn] = list (colresult);
        
        # negative-sense
        colresult = map(lambda predrow: check_any_overlap (virusfeaturestart, virusfeatureend, predrow[1]['StartCoord'], predrow[1]['EndCoord']), data_predictions_revcomp.iterrows ())
        data_predictions_revcomp[newLogitFeatureColumn] = list (colresult);

# %% [markdown]
# Filter miR's based on desired attributes

# %%
data_bothstrands = pd.concat ([data_predictions_sense, data_predictions_revcomp], axis=0, ignore_index=True);

scoredcolumnnames = [];
for index, virusfeaturerow in data_virusfeatures.iterrows ():
    
    # these are the features we'll include scores for
    if (virusfeaturerow['Category'] == 'TRS' or 
        virusfeaturerow['Category'] == 'SLIP' or
        virusfeaturerow['Category'] == 'KNOT' or
        virusfeaturerow['Category'] == 'STARTGENE'):
        
        newLogitFeatureColumn = "%s|%s" % (virusfeaturerow['Category'], virusfeaturerow['Subcategory']);
        scoredcolumnnames.append (newLogitFeatureColumn);
        
mirscores = {};
for _, datarow in data_bothstrands.iterrows ():
    if (datarow[scoredcolumnnames].sum() > 0):
        if mirscores.get (datarow[0]) == None:
            mirscores[datarow[0]] = 1;
        else:
            mirscores[datarow[0]] = mirscores[datarow[0]] + 1;

# %%
sorted_mirscores = sorted(mirscores.items(), key=operator.itemgetter(1), reverse=True)
scores = list (mirscores.values ());
minvalue = 1; # must have at least 1 intersection with a special feature
survivedmirs = [k for k,v in mirscores.items() if int(v) >= minvalue]

# %%
# read in miR coordinates (which are already sorted)
fn_sortedmircoords = "data/mature.coords.sorted.dupsallowed.mirbase22.5cols.txt";
data_sortedmircoords = pd.read_csv(fn_sortedmircoords, sep="\t", header=None)

# %%
col_coordfile_mirname = 4; # 0-indexed column that includes the miR name inside fn_sortedmircoords 
col_coordfile_chrom = 0;
col_coordfile_start = 2;

clusterddistance = 10000; # tag miR's if they are within this many NT from the start site of the previous regardless of strand
prevmir_chrom = None;
premir_start = None;

clusternum = 0;
clusteroutput = {};
emptyclusterrecord = { "uniquelocations": 0,
                       "numincluster": 0,
                       "details": ""
                     };

for index, sortedmircoords in data_sortedmircoords.iterrows():
    for survivedmir in survivedmirs:
        if survivedmir == sortedmircoords[col_coordfile_mirname]:
            appendtext = "";
            
            if ((sortedmircoords[col_coordfile_chrom] == prevmir_chrom) and
               (sortedmircoords[col_coordfile_start] - premir_start <= clusterddistance)):
        
                appendtext = "POTENTIAL CLUSTER: this miR is %d distance from the previously listed miR\n" % (sortedmircoords[col_coordfile_start] - premir_start);
            else:
                clusternum += 1;
                clusteroutput[clusternum] = dict (emptyclusterrecord);

            clusteroutput[clusternum]["numincluster"] += 1;
            clusteroutput[clusternum]["uniquelocations"] += mirscores[survivedmir];
            appendtext += "miR: %s (total uniq predicted binding locations: %d)\n" % (survivedmir, mirscores[survivedmir]);
            
            matchmir = data_bothstrands.loc[(data_bothstrands[0] == survivedmir) & (data_bothstrands["strand"] == 'positive-sense'), scoredcolumnnames];
            nonzeros = matchmir.sum()>0;
            if (sum (nonzeros) > 0):
                appendtext += "Positive-Sense: \n";
                appendtext += matchmir.sum()[nonzeros].to_string ();
                appendtext += "\n\n";

            matchmir = data_bothstrands.loc[(data_bothstrands[0] == survivedmir) & (data_bothstrands["strand"] == 'negative-sense'), scoredcolumnnames];    
            nonzeros = matchmir.sum()>0;
            if (sum (nonzeros) > 0):
                appendtext += "Negative-Sense: \n";
                appendtext += matchmir.sum()[nonzeros].to_string ();
                appendtext += "\n\n";
                
            clusteroutput[clusternum]["details"] += appendtext;
            
            prevmir_chrom = sortedmircoords[col_coordfile_chrom];
            premir_start = sortedmircoords[col_coordfile_start];

# %%
# sort hash in desending order by uniquelocations & numincluster
sortedoutput = [v for k, v in sorted(clusteroutput.items(), key=lambda item: (-item[1]["uniquelocations"], -item[1]["numincluster"]))]

for sortoutput in sortedoutput:
    print ("---------------- Cluster Start -----------------------------------")
    print ("unique_predicted_target_locations: %d" % (sortoutput["uniquelocations"]))
    print ("number_of_miRNAs_in_cluster: %d" % (sortoutput["numincluster"]))
    print ("%s" % (sortoutput["details"]))
    print ();
# Out:
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 7
# number_of_miRNAs_in_cluster: 7
# miR: hsa_miR_512_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10    1
#
# POTENTIAL CLUSTER: this miR is 2484 distance from the previously listed miR
# miR: hsa_miR_512_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10    1
#
# POTENTIAL CLUSTER: this miR is 9840 distance from the previously listed miR
# miR: hsa_miR_515_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 938 distance from the previously listed miR
# miR: hsa_miR_519e_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 5068 distance from the previously listed miR
# miR: hsa_miR_515_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 5874 distance from the previously listed miR
# miR: hsa_miR_520a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 7504 distance from the previously listed miR
# miR: hsa_miR_523_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 6
# number_of_miRNAs_in_cluster: 4
# miR: hsa_let_7a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 832 distance from the previously listed miR
# miR: hsa_miR_4763_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|6    1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_4763_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|S    1
#
# Negative-Sense:
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 67 distance from the previously listed miR
# miR: hsa_let_7b_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# STARTGENE|3b    1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 5
# number_of_miRNAs_in_cluster: 5
# miR: hsa_miR_541_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|N     1
# STARTGENE|9a    1
#
# POTENTIAL CLUSTER: this miR is 798 distance from the previously listed miR
# miR: hsa_miR_409_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|N           1
# STARTGENE|N     1
# STARTGENE|9a    1
#
# POTENTIAL CLUSTER: this miR is 579 distance from the previously listed miR
# miR: hsa_miR_410_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# KNOT|3putrPseudoknotSL1    1
# KNOT|3putrPseudoknotSL1    1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_410_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 770 distance from the previously listed miR
# miR: hsa_miR_656_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# KNOT|3putrPseudoknotSL1    1
# KNOT|3putrPseudoknotSL1    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 4
# number_of_miRNAs_in_cluster: 4
# miR: hsa_miR_337_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
# POTENTIAL CLUSTER: this miR is 560 distance from the previously listed miR
# miR: hsa_miR_665 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
# POTENTIAL CLUSTER: this miR is 5951 distance from the previously listed miR
# miR: hsa_miR_431_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 3470 distance from the previously listed miR
# miR: hsa_miR_432_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 4
# number_of_miRNAs_in_cluster: 4
# miR: hsa_miR_323a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|3a          1
# STARTGENE|3a    1
#
# POTENTIAL CLUSTER: this miR is 1015 distance from the previously listed miR
# miR: hsa_miR_329_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|3b    1
#
# POTENTIAL CLUSTER: this miR is 317 distance from the previously listed miR
# miR: hsa_miR_329_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|3b    1
#
# POTENTIAL CLUSTER: this miR is 2947 distance from the previously listed miR
# miR: hsa_miR_1193 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 4
# number_of_miRNAs_in_cluster: 4
# miR: hsa_miR_518c_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|1AB    1
#
# POTENTIAL CLUSTER: this miR is 3563 distance from the previously listed miR
# miR: hsa_miR_517a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 8797 distance from the previously listed miR
# miR: hsa_miR_517b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 1064 distance from the previously listed miR
# miR: hsa_miR_520g_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 4
# number_of_miRNAs_in_cluster: 3
# miR: hsa_miR_449a (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|6    1
#
# Negative-Sense:
# TRS|10    1
#
# POTENTIAL CLUSTER: this miR is 120 distance from the previously listed miR
# miR: hsa_miR_449b_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10    1
#
# POTENTIAL CLUSTER: this miR is 1607 distance from the previously listed miR
# miR: hsa_miR_449c_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 4
# number_of_miRNAs_in_cluster: 3
# miR: hsa_miR_19b_2_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# Negative-Sense:
# STARTGENE|3b    1
#
# POTENTIAL CLUSTER: this miR is 86 distance from the previously listed miR
# miR: hsa_miR_20b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
# POTENTIAL CLUSTER: this miR is 395 distance from the previously listed miR
# miR: hsa_miR_106a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 4
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4758_5p (total uniq predicted binding locations: 4)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# TRS|E                     1
# STARTGENE|E               1
# STARTGENE|6               1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 3
# miR: hsa_miR_302a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 180 distance from the previously listed miR
# miR: hsa_miR_302c_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 123 distance from the previously listed miR
# miR: hsa_miR_302b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_6753_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
# POTENTIAL CLUSTER: this miR is 138 distance from the previously listed miR
# miR: hsa_miR_6753_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|1AB                   1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_4539 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|N           1
# STARTGENE|N     1
# STARTGENE|9a    1
#
# POTENTIAL CLUSTER: this miR is 612 distance from the previously listed miR
# miR: hsa_miR_4507 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|10                    1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_33b_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# STARTGENE|9b    1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_33b_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_1199_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|10    1
#
# POTENTIAL CLUSTER: this miR is 44 distance from the previously listed miR
# miR: hsa_miR_1199_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    2
# SLIP|1ab_frameshiftSL2    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_550a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 41 distance from the previously listed miR
# miR: hsa_miR_550a_3_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|7a          1
# STARTGENE|7a    1
#
# Negative-Sense:
# TRS|E    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_550a_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|7a          1
# STARTGENE|7a    1
#
# Negative-Sense:
# TRS|E    1
#
# POTENTIAL CLUSTER: this miR is 39 distance from the previously listed miR
# miR: hsa_miR_550a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_550a_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|7a          1
# STARTGENE|7a    1
#
# Negative-Sense:
# TRS|E    1
#
# POTENTIAL CLUSTER: this miR is 39 distance from the previously listed miR
# miR: hsa_miR_550a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3620_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# TRS|E          1
# TRS|10         1
# STARTGENE|E    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6759_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    2
# SLIP|1ab_frameshiftSL2    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4498 (total uniq predicted binding locations: 3)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5572 (total uniq predicted binding locations: 3)
# Positive-Sense:
# TRS|1AB         1
# TRS|10          1
# STARTGENE|N     1
# STARTGENE|9a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6785_5p (total uniq predicted binding locations: 3)
# Positive-Sense:
# TRS|6           1
# STARTGENE|10    1
#
# Negative-Sense:
# STARTGENE|7b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_658 (total uniq predicted binding locations: 3)
# Positive-Sense:
# TRS|E           1
# STARTGENE|10    1
#
# Negative-Sense:
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 3
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6850_5p (total uniq predicted binding locations: 3)
# Negative-Sense:
# TRS|10                    1
# STARTGENE|10              1
# SLIP|1ab_frameshiftSL1    2
# SLIP|1ab_frameshiftSL2    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_3116 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_3116 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_3120_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 37 distance from the previously listed miR
# miR: hsa_miR_214_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_3158_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 39 distance from the previously listed miR
# miR: hsa_miR_3158_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_let_7i_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|3b    1
#
# POTENTIAL CLUSTER: this miR is 56 distance from the previously listed miR
# miR: hsa_let_7i_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_19a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 303 distance from the previously listed miR
# miR: hsa_miR_19b_1_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_4717_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|3b    1
#
# POTENTIAL CLUSTER: this miR is 32 distance from the previously listed miR
# miR: hsa_miR_4717_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|3a          1
# STARTGENE|3a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_187_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|E    1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_187_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_4745_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 8686 distance from the previously listed miR
# miR: hsa_miR_3187_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_519a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 9948 distance from the previously listed miR
# miR: hsa_miR_519a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_4776_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
# POTENTIAL CLUSTER: this miR is 40 distance from the previously listed miR
# miR: hsa_miR_4776_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_6811_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_6811_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_2467_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|3b    1
#
# POTENTIAL CLUSTER: this miR is 39 distance from the previously listed miR
# miR: hsa_miR_2467_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_10401_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 2527 distance from the previously listed miR
# miR: hsa_miR_10396b_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_6508_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 32 distance from the previously listed miR
# miR: hsa_miR_6508_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_143_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 34 distance from the previously listed miR
# miR: hsa_miR_143_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_4659a_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|M    1
#
# POTENTIAL CLUSTER: this miR is 36 distance from the previously listed miR
# miR: hsa_miR_4659b_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_486_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
# POTENTIAL CLUSTER: this miR is 43 distance from the previously listed miR
# miR: hsa_miR_486_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_3150b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|7a    1
#
# POTENTIAL CLUSTER: this miR is 38 distance from the previously listed miR
# miR: hsa_miR_3150a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_7112_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# POTENTIAL CLUSTER: this miR is 43 distance from the previously listed miR
# miR: hsa_miR_7112_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_let_7a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 2879 distance from the previously listed miR
# miR: hsa_let_7d_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_221_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# POTENTIAL CLUSTER: this miR is 856 distance from the previously listed miR
# miR: hsa_miR_222_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 2
# miR: hsa_miR_4536_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
# POTENTIAL CLUSTER: this miR is 67 distance from the previously listed miR
# miR: hsa_miR_4536_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4632_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|6    1
#
# Negative-Sense:
# TRS|7a          1
# STARTGENE|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4253 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6734_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# STARTGENE|6    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6735_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4421 (total uniq predicted binding locations: 2)
# Positive-Sense:
# STARTGENE|E    1
#
# Negative-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_2682_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# STARTGENE|10              1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6736_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5087 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|E    1
#
# Negative-Sense:
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1295a (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|M    1
#
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4690_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|7a          1
# TRS|10          1
# STARTGENE|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_139_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_125b_1_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6090 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4701_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3198 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|6    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1228_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|E                     1
# STARTGENE|E               1
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_8075 (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|10          1
# SLIP|slip1ab    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4505 (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|E           1
# TRS|10          1
# STARTGENE|E     1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6765_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|7a          1
# STARTGENE|3b    1
# STARTGENE|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1225_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|E                     1
# STARTGENE|E               1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6511b_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|8           1
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_193b_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# STARTGENE|3b    1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3180_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6511b_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|8           1
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3180_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3180_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_744_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# STARTGENE|3b    1
#
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_423_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# STARTGENE|6    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4726_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|M    1
#
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4727_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|6    1
#
# Negative-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6786_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|S          1
# STARTGENE|S    1
#
# Negative-Sense:
# TRS|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4741 (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4527 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
# TRS|10     1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7108_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|10          1
# STARTGENE|10    1
#
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1238_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# TRS|E          1
# STARTGENE|E    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6796_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5088_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# STARTGENE|10              1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6800_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# STARTGENE|6               1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4749_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5001_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_10396a_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# STARTGENE|3b              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_let_7c_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# STARTGENE|3b    1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4327 (total uniq predicted binding locations: 2)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3198 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|6    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6083 (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|10                    1
# STARTGENE|10              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7978 (total uniq predicted binding locations: 2)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# SLIP|slip1ab    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_12115 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|6          1
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_574_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|E          1
# STARTGENE|E    1
#
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_2277_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|E                     1
# STARTGENE|E               1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3655 (total uniq predicted binding locations: 2)
# Positive-Sense:
# KNOT|3putrPseudoknotSL1    1
# KNOT|3putrPseudoknotSL1    1
#
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6499_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|S          1
# TRS|10         1
# STARTGENE|S    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3141 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|1AB    1
#
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1229_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|3a          1
# TRS|E           1
# STARTGENE|3a    1
# STARTGENE|E     1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4640_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|M    1
#
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6721_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|E           1
# STARTGENE|E     1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4656 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|M                     1
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7160_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# STARTGENE|3b    1
#
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_383_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|M    1
#
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1207_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# STARTGENE|S    1
#
# Negative-Sense:
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4474_3p (total uniq predicted binding locations: 2)
# Positive-Sense:
# SLIP|1ab_frameshiftSL2    1
#
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4672 (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|10                    1
# STARTGENE|10              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6855_5p (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|N           1
# STARTGENE|N     1
# STARTGENE|9a    1
#
# Negative-Sense:
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6722_3p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    2
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1587 (total uniq predicted binding locations: 2)
# Positive-Sense:
# TRS|M                     1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 2
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6858_5p (total uniq predicted binding locations: 2)
# Negative-Sense:
# TRS|7a          1
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6726_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4689 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_34a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6729_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|E          1
# STARTGENE|E    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6730_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1290 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4684_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4425 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3605_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_552_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_30e_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|slip1ab    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4781_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_101_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7156_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_760 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_7852_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_197_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4257 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4259 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_921 (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|S    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_557 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1231 (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|N     1
# STARTGENE|9a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6740_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_135b_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ...
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6075 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3650 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_12130 (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3661 (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_874_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1294 (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1303 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_103a_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_218_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|E    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_219a_1_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6834_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|3b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4642 (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5685 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_2113 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6836_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_589_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1183 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3147 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4651 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_12119 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_106b_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3666 (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_183_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# KNOT|3putrPseudoknotSL1    1
# KNOT|3putrPseudoknotSL1    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_490_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_11400 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|slip1ab    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3907 (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_595 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_8055 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4660 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_124_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3622a_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|E          1
# STARTGENE|E    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_124_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1204 (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1208 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_5194 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|7a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_151a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_661 (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|E    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_939_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6893_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_10400_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_101_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4289 (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_2278 (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|slip1ab    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_23b_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3911 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6877_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4674 (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_602 (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3690 (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4767 (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4768_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|M    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_4666b (total uniq predicted binding locations: 1)
# Positive-Sense:
# SLIP|slip1ab              1
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_500a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_6894_5p (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|1AB    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1321 (total uniq predicted binding locations: 1)
# Positive-Sense:
# TRS|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1298_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|6    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_450a_2_3p (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|N     1
# STARTGENE|9a    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_891a_3p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_2114_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# SLIP|1ab_frameshiftSL1    1
# SLIP|1ab_frameshiftSL2    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_664b_5p (total uniq predicted binding locations: 1)
# Negative-Sense:
# TRS|10          1
# STARTGENE|10    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1184 (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1184 (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_1184 (total uniq predicted binding locations: 1)
# Negative-Sense:
# STARTGENE|9b    1
#
#
#
# ---------------- Cluster Start -----------------------------------
# unique_predicted_target_locations: 1
# number_of_miRNAs_in_cluster: 1
# miR: hsa_miR_3690 (total uniq predicted binding locations: 1)
# Positive-Sense:
# STARTGENE|6    1
